# %%
import pandas as pd

nba = pd.read_csv('https://raw.githubusercontent.com/aaubs/ds-master/main/data/NBA_Data.csv')

# %%
nba.head()
# Out:
#    Unnamed: 0                 PLAYER TEAM  AGE  GP   W   L   MIN   PTS   FGM  \
# 0           1           James Harden  HOU   29  78  51  27  36.8  36.1  10.8
# 1           2            Paul George  OKC   29  77  46  31  36.9  28.0   9.2
# 2           3  Giannis Antetokounmpo  MIL   24  72  56  16  32.8  27.7  10.0
# 3           4            Joel Embiid  PHI   25  64  43  21  33.7  27.5   9.1
# 4           5           LeBron James  LAL   34  55  28  27  35.2  27.4  10.1
#
#    ...   REB  AST  TOV  STL  BLK   PF    FP  DD2  TD3  +/-
# 0  ...   6.6  7.5  5.0  2.0  0.7  3.1  58.7   34    7  4.6
# 1  ...   8.2  4.1  2.7  2.2  0.4  2.8  49.3   24    1  6.4
# 2  ...  12.5  5.9  3.7  1.3  1.5  3.2  56.2   54    5  9.1
# 3  ...  13.6  3.7  3.5  0.7  1.9  3.3  53.7   58    2  5.8
# 4  ...   8.5  8.3  3.6  1.3  0.6  1.7  52.0   32    8  2.1
#
# [5 rows x 30 columns]

# %%
df.head()
